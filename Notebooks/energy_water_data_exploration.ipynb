# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Load the Data**

# %% [markdown]
# The energy and water data can be downloaded from the following webpage:
#
# https://data.cityofnewyork.us/Environment/Energy-and-Water-Data-Disclosure-for-Local-Law-84-/7x5e-2fxh/about_data

# %%
energy_water_data = pd.read_csv('/content/drive/MyDrive/mlc_projects/data/raw/local_law_84.csv')
# Out:
# <ipython-input-17-ed20f437ef17>:1: DtypeWarning: Columns (9,15,216,217) have mixed types. Specify dtype option on import or set low_memory=False.
#   energy_water_data = pd.read_csv('/content/drive/MyDrive/mlc_projects/data/raw/local_law_84.csv')

# %% [markdown]
# ### **Explore Data Structure**
# Display the first few rows of the datasets to understand the structure and format of the data.
#
# Check the data types of each column (numeric, categorical, date, etc.).
#
# Inspect the dimensions of the datasets (number of rows and columns).

# %%
energy_water_data
# Out:
#        Property Id                     Property Name  \
# 0         21205224             Astoria Blvd Property
# 1          2665352     Stellar - 70 West 93rd Street
# 2          2665400  Stellar - 28-50 West 97th Street
# 3          2665405        Stellar - 310 Greenwich St
# 4          2665415       Stellar - 87 Hamilton Place
# ...            ...                               ...
# 29837      6245271              A&Y Management, Inc.
# 29838      8886078        * TEST - Flatiron Building
# 29839      6317603                 Five Boro Storage
# 29840      6128948                            Howard
# 29841      6128959                        Building 1
#
#                         Parent Property Id  \
# 0      Not Applicable: Standalone Property
# 1                                 20599688
# 2      Not Applicable: Standalone Property
# 3      Not Applicable: Standalone Property
# 4      Not Applicable: Standalone Property
# ...                                    ...
# ...

# %%
selected_columns = ['Property Id',
                    'Parent Property Id',
                    'City',
                    'Postal Code',
                    'Primary Property Type - Self Selected',
                    'Primary Property Type - Portfolio Manager-Calculated',
                    'National Median Reference Property Type',
                    'List of All Property Use Types at Property',
                    'Largest Property Use Type',
                    'Largest Property Use Type - Gross Floor Area (ft²)',
                    '2nd Largest Property Use Type',
                    '2nd Largest Property Use - Gross Floor Area (ft²)',
                    '3rd Largest Property Use Type',
                    '3rd Largest Property Use Type - Gross Floor Area (ft²)',
                    'Year Built',
                    'Construction Status',
                    'Number of Buildings',
                    'Occupancy',
                    'Metered Areas (Energy)',
                    'ENERGY STAR Score',
                    'National Median ENERGY STAR Score',
                    'Target ENERGY STAR Score',
                    'ENERGY STAR Certification - Eligibility',
                    'ENERGY STAR Certification - Last Approval Date',
                    'Site EUI (kBtu/ft²)',
                    'Site Energy Use (kBtu)',
                    'Weather Normalized Site Energy Use (kBtu)',
                    'Weather Normalized Site Electricity Intensity (kWh/ft²)',
                    'Source EUI (kBtu/ft²)',
                    'Weather Normalized Source EUI (kBtu/ft²)',
                    'National Median Source EUI (kBtu/ft²)',
                    'Source Energy Use (kBtu)',
                    'Weather Normalized Source Energy Use (kBtu)',
                    'Electricity Use - Grid Purchase (kBtu)',
                    'Electricity Use - Grid Purchase (kWh)',
                    'Weather Normalized Site Electricity (kWh)',
                    'Electricity Use - Grid Purchase and Generated from Onsite Renewable Systems (kWh)',
                    'Electricity Use - Grid Purchase and Generated from Onsite Renewable Systems (kBtu)',
                    'Electricity Use – Generated from Onsite Renewable Systems and Used Onsite (kWh)',
                    'Electricity Use – Generated from Onsite Renewable Systems and Used Onsite (kBtu)',
                    'Electricity Use – Generated from Onsite Renewable Systems (kWh)',
                    'Electricity Use – Generated from Onsite Renewable Systems and Exported (kWh)',
                    'Green Power - Offsite (kWh)',
                    'Green Power - Onsite and Offsite (kWh)',
                    'Percent of Electricity that is Green Power',
                    'Percent of RECs Retained']

energy_water_data = energy_water_data[selected_columns]

# %% [markdown]
# Based on the output above, we can see that the majority of the columns are stored as string objects.
#
# Many of the rows are categorical, but many others are numerical and still require conversion
#
# We will need to convert relevant rows to the appropriate data type before processing.
#
#
# Some columns of interest are as follows:
# - Property Id
# - Property Name
# - Parent Property Id
# - Parent Property Name
# - NYC Borough, Block and Lot (BBL)
# - NYC Building Identification Number (BIN)
# - Address 1
# - City
# - Postal Code
# - Primary Property Type - Self Selected
# - Primary Property Type - Portfolio Manager-Calculated
# - National Median Reference Property Type
# - List of All Property Use Types at Property
# - Largest Property Use Type
# - Largest Property Use Type - Gross Floor Area (ft²)
# - 2nd Largest Property Use Type
# - 2nd Largest Property Use - Gross Floor Area (ft²)
# - 3rd Largest Property Use Type
# - 3rd Largest Property Use Type - Gross Floor Area (ft²)
# - Year Built
# - Number of Buildings
# - Occupancy
# - Metered Areas (Energy)
# - Metered Areas (Water)
# - ENERGY STAR Score
#
# - and MORE!!!
#
# We need to work together to determine what features we want to keep **OR** determine what features we definitely don't want and drop them.
#
# ### Sampling the Dataset
# We need to determine how we will sample this dataset.
# - We will focus only on buildings whose primary property use type is 'Multifamily Housing'
#
#
# ### Cleaning the Dataset
# - We need our rows to have data for Site Energy Use
# - Do we only want buildings that have received ENERGY STAR rating?

# %%
# the original data has string 'Not Available' instead of null values, which hinders dtype inference
energy_water_data.replace('Not Available', np.nan, inplace=True)

df = pd.DataFrame({'ints': ['3', '5'], 'Words': ['Kobe', 'Bryant']})
df.apply(pd.to_numeric, errors='ignore').info()

energy_water_data = energy_water_data.infer_objects()
energy_water_data.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ints    2 non-null      int64
#  1   Words   2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes
# Property Id                                                                            int64
# Parent Property Id                                                                    object
# City                                                                                  object
# Postal Code                                                                           object
# Primary Property Type - Self Selected                                                 object
# Primary Property Type - Portfolio Manager-Calculated                                  object
# National Median Reference Property Type                                               object
# ...

# %%
len(energy_water_data.columns)
# Out:
# 46

# %% [markdown]
# ## Data Dictionary for Selected Columns
#
# | Column Name                                                  | Short Description |
# |--------------------------------------------------------------|-------------------|
# | **Property Id**                                              | Unique property identifiers. |
# | **Parent Property Id**                                       | Identifier for the parent property, used for campuses. |
# | **City**                                                     | Self-reported city of the property. |
# | **Postal Code**                                              | Self-reported postal code of the property. |
# | **Primary Property Type - Self Selected**                    | Primary property type selected for reporting. |
# | **Primary Property Type - Portfolio Manager-Calculated**     | Primary property type calculated by Portfolio Manager. |
# | **National Median Reference Property Type**                  | National median reference for property type. |
# | **List of All Property Use Types at Property**               | All property use types present at the property. |
# | **Largest Property Use Type**                                | Largest property use type by area. |
# | **Largest Property Use Type - Gross Floor Area (ft²)**       | Gross floor area of the largest property use type. |
# | **2nd Largest Property Use Type**                            | Second largest property use type. |
# | **2nd Largest Property Use - Gross Floor Area (ft²)**        | Gross floor area of the second largest property use type. |
# | **3rd Largest Property Use Type**                            | Third largest property use type. |
# | **3rd Largest Property Use Type - Gross Floor Area (ft²)**   | Gross floor area of the third largest property use type. |
# | **Year Built**                                               | Year the property was built. |
# | **Construction Status**                                      | Construction status of the property. |
# | **Number of Buildings**                                      | Number of buildings on the property. |
# | **Occupancy**                                                | Occupancy percentage of the property. |
# | **Metered Areas (Energy)**                                   | Areas of the property that are metered for energy. |
# | **ENERGY STAR Score**                                        | ENERGY STAR score of the property. |
# | **National Median ENERGY STAR Score**                        | National median ENERGY STAR score. |
# | **Target ENERGY STAR Score**                                 | Target ENERGY STAR score for the property. |
# | **ENERGY STAR Certification - Eligibility**                  | Eligibility status for ENERGY STAR certification. |
# | **ENERGY STAR Certification - Last Approval Date**           | Last approval date for ENERGY STAR certification. |
# | **Site EUI (kBtu/ft²)**                                      | Energy use intensity at the site. |
# | **Weather Normalized Site Energy Use (kBtu)**                | Weather normalized energy use at the site. |
# | **Weather Normalized Site Electricity Intensity (kWh/ft²)**  | Weather normalized electricity intensity at the site. |
# | **Source EUI (kBtu/ft²)**                                    | Source energy use intensity. |
# | **Weather Normalized Source EUI (kBtu/ft²)**                 | Weather normalized source energy use intensity. |
# | **National Median Source EUI (kBtu/ft²)**                    | National median source energy use intensity. |
# | **Source Energy Use (kBtu)**                                 | Total source energy use. |
# | **Weather Normalized Source Energy Use (kBtu)**              | Weather normalized total source energy use. |
# | **Electricity Use - Grid Purchase (kBtu)**                   | Electricity purchased from the grid. |
# | **Electricity Use - Grid Purchase (kWh)**                    | Electricity purchased from the grid in kWh. |
# | **Weather Normalized Site Electricity (kWh)**                | Weather normalized electricity use at the site. |
# | **Electricity Use - Grid Purchase and Generated from Onsite Renewable Systems (kWh)** | Electricity from grid and onsite renewables in kWh. |
# | **Electricity Use - Grid Purchase and Generated from Onsite Renewable Systems (kBtu)** | Electricity from grid and onsite renewables in kBtu. |
# | **Electricity Use – Generated from Onsite Renewable Systems and Used Onsite (kWh)** | Onsite generated and used renewable electricity in kWh. |
# | **Electricity Use – Generated from Onsite Renewable Systems and Used Onsite (kBtu)** | Onsite generated and used renewable electricity in kBtu. |
# | **Electricity Use – Generated from Onsite Renewable Systems (kWh)** | Total onsite generated renewable electricity in kWh. |
# | **Electricity Use – Generated from Onsite Renewable Systems and Exported (kWh)** | Exported onsite generated renewable electricity in kWh. |
# | **Green Power - Offsite (kWh)**                             | Purchased offsite green power in kWh. |
# | **Green Power - Onsite and Offsite (kWh)**                   | Total onsite and offsite green power in kWh. |
# | **Percent of Electricity that is Green Power**               | Percentage of electricity from green power sources. |
# | **Percent of RECs Retained**                                 | Percentage of Renewable Energy Certificates retained. |

# %% [markdown]
# ### **Summary Statistics**
# Compute summary statistics for numeric variables (mean, median, min, max, standard deviation, etc.).
#
# Count unique values for categorical variables.

# %% [markdown]
# ### **Handle Missing Values**:
# Identify and count missing values in the datasets. In this dataset, we should not expect any of the rows to have data for every column.
#
# Therefore, we need to decide on an appropriate strategy to handle missing values (imputation, removal, etc.).
#
# Perhaps we should drop the buildings that do not have an ENERGY STAR score.

# %% [markdown]
# ### **Data Distribution**
# Plot histograms or density plots to visualize the distribution of numeric variables.
#
# For categorical variables, create bar plots to visualize the frequency distribution of each category.

# %% [markdown]
# ### **Correlation Analysis**
# How can we compare pairwise correlations between numeric variables?
#
# It would be nice to visualize correlations using heatmaps or scatter plots, but there are 200+ variables.

# %% [markdown]
# ### **Outlier Detection**
# Identify outliers in the data using visualization techniques such as box plots or scatter plots.

# %% [markdown]
# ### **Data Visualization**
# Create some visualizations to explore relationships between variables and identify patterns in the data.

# %% [markdown]
# ### **Understand Class Imbalance** (for classification tasks)
# Check the distribution of target classes to identify any class imbalances that may need to be addressed during modeling.

# %% [markdown]
# ### **Cross-Tabulations and Pivot Tables**
# Create cross-tabulations and pivot tables to analyze relationships between categorical variables.

# %% [markdown]
# ### **Data Transformation**
#
# Do we want to use normalization or scaling on the dataset?
